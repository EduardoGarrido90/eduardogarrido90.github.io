# %% [markdown]
# # Práctica Día 17 — Orquestador con fallbacks
#
# Mini-orquestador que implementa cinco patrones de fallback.

# %%
import sys; sys.path.insert(0, '.')
from practica_17 import orchestrator, Session
for q in ['¿Comisión hipoteca?', '¿Color del café?']:
    print(q, '→', orchestrator(q, Session()))

# %% [markdown]
# ## Ejercicios
#
# **17.1.** Añade un fallback de timeout: si una llamada tarda más de 1 segundo, cancela y devuelve respuesta parcial.
# **17.2.** Diseña la arquitectura multi-agente del proyecto final de tu grupo (boceto en papel y descrito aquí).
# **17.3 (sin IA).** Defiende en 8 líneas por qué los fallbacks no son opcionales en producción.
