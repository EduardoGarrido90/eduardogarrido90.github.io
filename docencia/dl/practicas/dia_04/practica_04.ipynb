# %% [markdown]
# # Práctica Día 04 — Primera CNN sobre Fashion-MNIST
#
# Compara un MLP plano contra una CNN simple y, opcionalmente, una ResNet-18 preentrenada en ImageNet.

# %%
import sys; sys.path.insert(0, '.')
from practica_04 import load_fashion, MLP, SimpleCNN, train
from pathlib import Path
Xtr, ytr, Xte, yte = load_fashion(Path('~/.cache/fashion').expanduser())
Xtr.shape, Xte.shape

# %%
acc_mlp = train(MLP(), Xtr, ytr, Xte, yte, epochs=5)

# %%
acc_cnn = train(SimpleCNN(), Xtr, ytr, Xte, yte, epochs=5)

# %% [markdown]
# ## Ejercicios
#
# **4.1.** Calcula a mano la convolución de un kernel 3×3 sobre un parche que tú elijas de Xtr[0].
# **4.2.** Sustituye SimpleCNN por una ResNet-18 preentrenada (`torchvision.models.resnet18(weights='DEFAULT')`) con cabeza nueva de 10 clases. ¿Qué accuracy obtienes con 3 épocas?
# **4.3 (sin IA).** ¿Por qué la CNN supera al MLP aunque ambos tengan número similar de parámetros?

# %% [markdown]
# ## Declaración de uso de IA
#
# | Sección | Herramienta | Para qué |
# |---|---|---|
# | Código | … | … |
# | Ejercicio 4.3 | Ninguna | — |
