# %% [markdown]
# # Práctica Día 09 — Multi-head self-attention a mano
#
# Verificación contra `torch.nn.MultiheadAttention`.

# %%
import sys; sys.path.insert(0, '.')
from practica_09 import multihead_self_attention
import numpy as np
rng = np.random.default_rng(0)
T, d_model, n_heads = 6, 16, 4
X = rng.normal(size=(T, d_model)).astype(np.float32)
Wq, Wk, Wv, Wo = (rng.normal(size=(d_model, d_model)).astype(np.float32)*0.1 for _ in range(4))
out = multihead_self_attention(X, Wq, Wk, Wv, Wo, n_heads)
out.shape, out.mean(), out.std()

# %% [markdown]
# ## Ejercicios
#
# **9.1.** Calcula a mano (con números) la salida de UN bloque para una frase de 3 tokens y dim 2.
# **9.2.** Carga `roberta-base-bne` y muestra los pesos de atención de las 4 primeras cabezas sobre la frase 'el banco aprueba la hipoteca'.
# **9.3 (sin IA).** Justifica en 8 líneas por qué Transformer ha sustituido a CNN en visión (ViT) y a LSTM en NLP, en términos de paralelismo y largo plazo.

# %% [markdown]
# ## Declaración de uso de IA
#
# | Sección | Herramienta | Para qué |
# |---|---|---|
# | Código | … | … |
# | Ejercicio 9.3 | Ninguna | — |
