# %% [markdown]
# # Práctica Día 14 — MCP + multi-agente
#
# Configurar un servidor MCP de filesystem y orquestar dos subagentes.

# %% [markdown]
# ## Pasos
#
# 1. Instala el servidor MCP de filesystem: `npx -y @modelcontextprotocol/server-filesystem /ruta/segura`.
# 2. Configura Claude Code para usarlo (`~/.claude/settings.json`).
# 3. Crea dos subagentes en `.claude/agents/` con `CLAUDE.md` propio: `investigador.md` y `redactor.md`.
# 4. Lanza al orquestador la tarea: *"Investiga este repo (subagente investigador) y redacta un README (subagente redactor)"*.
# 5. Pega aquí la transcripción y la traza JSON.

# %%
import sys; sys.path.insert(0, '.')
from practica_14 import simulate
simulate()

# %% [markdown]
# ## Ejercicios
#
# **14.1.** Configura un servidor MCP de Postgres apuntando a una base de datos sintética.
# **14.2.** Diseña los `CLAUDE.md` de dos subagentes y la división del trabajo.
# **14.3 (sin IA).** Defiende en 8 líneas qué nivel HITL aplicarías a un asistente comercial de BBVA y por qué.
