# %% [markdown]
# # Práctica Día 10 — Comparativa de familias
#
# Evaluar el mismo prompt sobre tres familias (denso, MoE, SSM) si tienes acceso al hardware. En su defecto, completa la tabla a mano con benchmarks publicados.

# %%
import sys; sys.path.insert(0, '.')
from practica_10 import MODELS
import pandas as pd
df = pd.DataFrame(MODELS)
df

# %% [markdown]
# ## Ejercicios
#
# **10.1.** Si tu modelo MoE activa 2 de 8 expertos por token, ¿cuál es el factor de ahorro respecto a un denso equivalente del mismo tamaño? Calcúlalo.
# **10.2.** Para un caso de RAG con documentos de 100 K tokens en total, ¿qué familia recomendarías y por qué?
# **10.3 (sin IA).** Defiende en 8 líneas frente al CTO de tu empresa por qué eligirías DeepSeek-V3 sobre Llama 3.3 dado un presupuesto mensual de 5.000 € en API.

# %% [markdown]
# ## Declaración de uso de IA
#
# | Sección | Herramienta | Para qué |
# |---|---|---|
# | Tabla | … | … |
# | Ejercicios 10.x | Ninguna | — |
