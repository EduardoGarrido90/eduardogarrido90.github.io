# %% [markdown]
# # Práctica Día 12 — Mini-storyboard publicitario
#
# Generar 4 imágenes + voz off con APIs gratuitas o locales. Reportar coste y tiempo. Si no tienes acceso a una API de imagen, dibuja la idea a mano y describe los prompts.
#
# ## Pipeline
# 1. LLM produce concepto de 60 palabras.
# 2. Difusión produce 4 imágenes.
# 3. TTS produce 20 s de voz off.
# 4. Reporte de coste y tiempo.

# %%
# !pip install -q diffusers transformers accelerate

# %% [markdown]
# ## Ejercicios
#
# **12.1.** Genera 4 imágenes con Stable Diffusion v1.5 (open-source) sobre el concepto que hayas elegido.
# **12.2.** Compara dos prompts: uno básico y otro con detalles (estilo, encuadre, luz). ¿Mejora la salida?
# **12.3 (sin IA).** Defiende en 8 líneas por qué la creatividad humana sigue siendo necesaria aunque los modelos generen bien técnicamente.

# %% [markdown]
# ## Declaración de uso de IA
#
# | Sección | Herramienta | Para qué |
# |---|---|---|
# | Concepto | … | … |
# | Imágenes | … | … |
# | 12.3 | Ninguna | — |
