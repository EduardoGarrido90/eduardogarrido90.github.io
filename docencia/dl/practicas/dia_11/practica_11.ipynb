# %% [markdown]
# # Práctica Día 11 — Cliente LLM unificado
#
# Mide tokens, latencia y coste sobre Ollama (gratis) y compáralo con un proveedor cloud (Anthropic, OpenAI). Si no tienes API, deja sólo Ollama.

# %%
import sys; sys.path.insert(0, '.')
from practica_11 import chat_ollama, TARIFAS
out, n_in, n_out, lat = chat_ollama('qwen2.5:3b', 'Explica RAG en 2 frases.', system='Eres profesor de IA.')
print(out); print(f'tokens={n_in}+{n_out} latencia={lat:.2f}s')

# %% [markdown]
# ## Ejercicios
#
# **11.1.** Lanza la misma pregunta a Qwen 2.5 (local), Llama 3.2 (local) y, si tienes API, a Claude o GPT. Compara calidad y latencia.
# **11.2.** Calcula el coste mensual si haces 10 000 sesiones/mes parecidas a la del ejercicio.
# **11.3 (sin IA).** Defiende en 8 líneas qué modelo elegirías para un asistente de Mercadona que responde dudas internas, con justificación económica.

# %% [markdown]
# ## Declaración de uso de IA
#
# | Sección | Herramienta | Para qué |
# |---|---|---|
# | Código | … | … |
# | Ejercicio 11.3 | Ninguna | — |
