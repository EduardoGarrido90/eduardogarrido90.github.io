# %% [markdown]
# # Práctica Día 18 — Checklist AI Act
#
# Rellena la plantilla generada por `practica_18.py` con los datos del proyecto AI-first del grupo. Es entregable obligatorio del Bloque III.

# %%
import sys; sys.path.insert(0, '.')
from practica_18 import CHECKLIST
print(CHECKLIST[:1500])

# %% [markdown]
# ## Ejercicios
#
# **18.1.** Clasifica tu proyecto AI-first en uno de los cuatro niveles AI Act.
# **18.2.** Documenta los cinco artículos relevantes (10, 12, 13, 14, 15) para tu caso concreto.
# **18.3 (sin IA).** Defiende en 8 líneas las decisiones de mitigación del proyecto frente al regulador.
